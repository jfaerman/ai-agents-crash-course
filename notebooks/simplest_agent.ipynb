# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(
    name="Nutrition Agent",
    instructions ="""
    You are a helpful assistant  giving out nutrition advice.
    You give concise answers. 
    """
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Agent", ...)
# - Final output (str):
#     Bananas are healthy as part of a balanced diet.
#
#     Key benefits:
#     - Good source of potassium, vitamin C, vitamin B6, and dietary fiber.
#     - Provide quick energy from natural sugars and starch.
#     - Support digestion and heart health; contain resistant starch when less ripe.
#
#     Things to note:
#     - About 90–110 kcal per medium banana; sugar content is higher than some fruits.
#     - If you’re watching blood sugar, ripe bananas are higher GI; pair with protein/fat to slow absorption.
#
#     Bottom line: a medium banana daily can be a nutritious, convenient addition for most people.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True
        )
# Out:
#  generally healthy as part of a balanced diet.
#
# Key points:
# - Nutrients: good source of potassium, vitamin B6, vitamin C, and dietary fiber.
# - Blood pressure & digestion: potassium supports heart function; fiber aids digestion.
# - Energy: natural sugars provide quick energy; pair with protein/fat to pace absorption.
# - Notes: about 100–110 calories per medium banana; taste and sugar rise as it ripens.
# - Considerations: people with kidney disease may need to monitor potassium; diabetics should count carbs as with other fruits.
#
# If you want, I can tailor this to your goals (weight loss, workouts, kidney health, etc.).

# %% [markdown]
# _Good Job!_
